# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

from mpl_toolkits.mplot3d import Axes3D

# %%
all_files = glob.glob("data" + "/*.csv")

# %%
datasets = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=False, header=0, sep=';')
    datasets.append(df)

# %%
datasets[0]
# Out:
#            timestamp  gameobject_name     pos_x     pos_y     pos_z   euler_x  \
# 0      1571825185110  PortalCameraRig  0.000000  4.050000  0.050000    0.0000
# 1      1571825185112    LeftEyeAnchor  0.000000  0.000000  0.000000  354.4752
# 2      1571825185113  PortalCameraRig  0.000000  4.050000  0.050000    0.0000
# 3      1571825185829    LeftEyeAnchor  3.783237  1.227061  0.727773  354.4752
# 4      1571825185830  PortalCameraRig  3.783237  5.277061  0.777773    0.0000
# ...              ...              ...       ...       ...       ...       ...
# 30890  1571825413631  PortalCameraRig  4.048957  5.402204  0.830221    0.0000
# 30891  1571825413636    LeftEyeAnchor  4.048957  1.352204  0.780222  337.3974
# 30892  1571825413636  PortalCameraRig  4.048957  5.402204  0.830221    0.0000
# 30893  1571825413667    LeftEyeAnchor  4.048957  1.352204  0.780222  337.3974
# 30894  1571825413667  PortalCameraRig  4.048957  5.402204  0.830221    0.0000
#
#         euler_y    euler_z
# 0        0.0000   0.000000
# 1      353.8314   0.035508
# 2        0.0000   0.000000
# 3      353.8314   0.035508
# 4        0.0000   0.000000
# ...         ...        ...
# 30890    0.0000   0.000000
# 30891   75.5564  41.169940
# 30892    0.0000   0.000000
# 30893   75.5564  41.169940
# 30894    0.0000   0.000000
#
# [30895 rows x 8 columns]

# %%
df = pd.concat(datasets).reset_index(drop=True)

# %%
df
# Out:
#            timestamp  gameobject_name     pos_x     pos_y     pos_z   euler_x  \
# 0      1571825185110  PortalCameraRig  0.000000  4.050000  0.050000    0.0000
# 1      1571825185112    LeftEyeAnchor  0.000000  0.000000  0.000000  354.4752
# 2      1571825185113  PortalCameraRig  0.000000  4.050000  0.050000    0.0000
# 3      1571825185829    LeftEyeAnchor  3.783237  1.227061  0.727773  354.4752
# 4      1571825185830  PortalCameraRig  3.783237  5.277061  0.777773    0.0000
# ...              ...              ...       ...       ...       ...       ...
# 30890  1571825413631  PortalCameraRig  4.048957  5.402204  0.830221    0.0000
# 30891  1571825413636    LeftEyeAnchor  4.048957  1.352204  0.780222  337.3974
# 30892  1571825413636  PortalCameraRig  4.048957  5.402204  0.830221    0.0000
# 30893  1571825413667    LeftEyeAnchor  4.048957  1.352204  0.780222  337.3974
# 30894  1571825413667  PortalCameraRig  4.048957  5.402204  0.830221    0.0000
#
#         euler_y    euler_z
# 0        0.0000   0.000000
# 1      353.8314   0.035508
# 2        0.0000   0.000000
# 3      353.8314   0.035508
# 4        0.0000   0.000000
# ...         ...        ...
# 30890    0.0000   0.000000
# 30891   75.5564  41.169940
# 30892    0.0000   0.000000
# 30893   75.5564  41.169940
# 30894    0.0000   0.000000
#
# [30895 rows x 8 columns]

# %%
datasets_player = []
datasets_constants = []
for i, row in df.iterrows():
    if row['gameobject_name'] == 'LeftEyeAnchor':
        datasets_player.append(row)
    else:
        datasets_constants.append(row)

# %%
df_player = pd.DataFrame(datasets_player)
df_constants = pd.DataFrame(datasets_constants)

# %%
df_player
# Out:
#            timestamp gameobject_name     pos_x     pos_y     pos_z    euler_x  \
# 1      1571825185112   LeftEyeAnchor  0.000000  0.000000  0.000000  354.47520
# 3      1571825185829   LeftEyeAnchor  3.783237  1.227061  0.727773  354.47520
# 5      1571825185858   LeftEyeAnchor  3.760740  1.240485  0.722089   30.85914
# 7      1571825185864   LeftEyeAnchor  3.753736  1.245015  0.719974   41.52697
# 9      1571825185879   LeftEyeAnchor  3.739303  1.253513  0.715804   42.79083
# ...              ...             ...       ...       ...       ...        ...
# 30885  1571825413543   LeftEyeAnchor  4.048957  1.352204  0.780222  337.39740
# 30887  1571825413574   LeftEyeAnchor  4.048957  1.352204  0.780222  337.39740
# 30889  1571825413631   LeftEyeAnchor  4.048957  1.352204  0.780222  337.39740
# 30891  1571825413636   LeftEyeAnchor  4.048957  1.352204  0.780222  337.39740
# 30893  1571825413667   LeftEyeAnchor  4.048957  1.352204  0.780222  337.39740
#
#         euler_y    euler_z
# 1      353.8314   0.035508
# 3      353.8314   0.035508
# 5      119.8288   1.309591
# 7      220.8411  31.829900
# 9      223.0887  34.054470
# ...         ...        ...
# 30885   75.5564  41.169940
# 30887   75.5564  41.169940
# 30889   75.5564  41.169940
# 30891   75.5564  41.169940
# 30893   75.5564  41.169940
#
# [15447 rows x 8 columns]

# %%
ax1 = df_player.plot.scatter(x='pos_x',
                     y='pos_z')

#set axes limits
ax1.set_xlim([-2,5])
ax1.set_ylim([-1,3])
# Out:
# (-1, 3)

# %%
df_constants
# Out:
#            timestamp  gameobject_name     pos_x     pos_y     pos_z  euler_x  \
# 0      1571825185110  PortalCameraRig  0.000000  4.050000  0.050000      0.0
# 2      1571825185113  PortalCameraRig  0.000000  4.050000  0.050000      0.0
# 4      1571825185830  PortalCameraRig  3.783237  5.277061  0.777773      0.0
# 6      1571825185858  PortalCameraRig  3.760740  5.290485  0.772089      0.0
# 8      1571825185864  PortalCameraRig  3.753736  5.295015  0.769974      0.0
# ...              ...              ...       ...       ...       ...      ...
# 30886  1571825413543  PortalCameraRig  4.048957  5.402204  0.830221      0.0
# 30888  1571825413574  PortalCameraRig  4.048957  5.402204  0.830221      0.0
# 30890  1571825413631  PortalCameraRig  4.048957  5.402204  0.830221      0.0
# 30892  1571825413636  PortalCameraRig  4.048957  5.402204  0.830221      0.0
# 30894  1571825413667  PortalCameraRig  4.048957  5.402204  0.830221      0.0
#
#        euler_y  euler_z
# 0          0.0      0.0
# 2          0.0      0.0
# 4          0.0      0.0
# 6          0.0      0.0
# 8          0.0      0.0
# ...        ...      ...
# 30886      0.0      0.0
# 30888      0.0      0.0
# 30890      0.0      0.0
# 30892      0.0      0.0
# 30894      0.0      0.0
#
# [15448 rows x 8 columns]
